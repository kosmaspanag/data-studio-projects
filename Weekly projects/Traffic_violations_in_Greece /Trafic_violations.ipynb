# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", 100)

# %%
df1 = pd.read_excel('/Users/kosmas/Desktop/Columbia_Data_Studio_Projects/data-studio-projects/Weekly projects/Traffic_violations_in_Greece /troxaia2015paravaseis.xls')
df1.head()
# Out:
#              Α.Ε.Α. - ΔΙΕΘΥΝΣΗ ΤΡΟΧΑΙΑΣ ΑΣΤΥΝΟΜΕΥΣΗΣ  Unnamed: 1  Unnamed: 2  \
# 0                                                NaN         NaN         NaN
# 1  Πίνακας επικίνδυνων παραβάσεων\n ΕΤΟΥΣ 2015-2014          NaN         NaN
# 2                                                NaN         NaN         NaN
# 3                                    ΕΙΔΟΣ ΠΑΡΑΒΑΣΗΣ      2015.0      2014.0
# 4                          Παραβίαση προτεραιότητας       3927.0      3836.0
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3    ΔΙΑΦΟΡΑ    ΠΟΣΟΣΤΟ
# 4         91  0.0237226

# %%
df1 = df1.drop(['Unnamed: 3','Unnamed: 4'], axis = 1)

# %%
df1 = df1.drop([0,1,2,3])

# %%
df1 = df1.rename(index=str, columns={'Α.Ε.Α. - ΔΙΕΘΥΝΣΗ ΤΡΟΧΑΙΑΣ ΑΣΤΥΝΟΜΕΥΣΗΣ': 'ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_',
                                   'Unnamed: 1': '2015',
                                   'Unnamed: 2': '2014'})
df1.head()
# Out:
#                 ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_     2015     2014
# 4      Παραβίαση προτεραιότητας    3927.0   3836.0
# 5  Παραβίαση ερυθρού Σηματοδότη   14564.0  13913.0
# 6          Αντικανονικοί ελιγμοί   5926.0   5137.0
# 7     Κίνηση στο αντίθετο ρεύμα   11695.0  12729.0
# 8      Αντικανονικό Προσπέρασμα    8406.0   8107.0

# %%
df1 = df1.reset_index()

# %%
df1 = df1.drop(columns=['index'])

# %%
df1 = df1.astype({"2015": int, "2014": int})

# %%
df1
# Out:
#                                      ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_    2015    2014
# 0                           Παραβίαση προτεραιότητας     3927    3836
# 1                       Παραβίαση ερυθρού Σηματοδότη    14564   13913
# 2                               Αντικανονικοί ελιγμοί    5926    5137
# 3                          Κίνηση στο αντίθετο ρεύμα    11695   12729
# 4                           Αντικανονικό Προσπέρασμα     8406    8107
# 5   Κίνηση στην αριστερή λωρίδα - Μη κίνηση στο άκ...     261     297
# 6                           Μη χρήση ζώνης ασφαλείας    29611   34526
# 7                        Μη χρήση παιδικών καθισμάτων     424     626
# 8                                   Μη χρήση κράνους    52783   54354
# 9                         Παραβάσεις οχημάτων (ΚΤΕΟ)    25130   30683
# 10                             Παραβάσεις \nταχύτητας  173476  156892
# 11                 Παραβίαση χρήσης κινητού τηλεφώνου   19730   23459
# ...

# %%
df2 = pd.read_excel('/Users/kosmas/Desktop/Columbia_Data_Studio_Projects/data-studio-projects/Weekly projects/Traffic_violations_in_Greece /troxaia2016_paravaseis.xls')
df2.head()
# Out:
#              Α.Ε.Α. - ΔΙΕΘΥΝΣΗ ΤΡΟΧΑΙΑΣ ΑΣΤΥΝΟΜΕΥΣΗΣ  Unnamed: 1  Unnamed: 2  \
# 0                                                NaN         NaN         NaN
# 1  Πίνακας επικίνδυνων παραβάσεων\n έτους 2016-2015          NaN         NaN
# 2                                                NaN         NaN         NaN
# 3                                    ΕΙΔΟΣ ΠΑΡΑΒΑΣΗΣ      2016.0      2015.0
# 4                          Παραβίαση προτεραιότητας       3733.0      3927.0
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3    ΔΙΑΦΟΡΑ    ΠΟΣΟΣΤΟ
# 4       -194 -0.0494016

# %%
df2 = df2.drop(['Unnamed: 3','Unnamed: 2','Unnamed: 4'], axis = 1)

# %%
df2 = df2.drop([0,1,2,3,20])

# %%
df2 = df2.rename(index=str, columns={'Α.Ε.Α. - ΔΙΕΘΥΝΣΗ ΤΡΟΧΑΙΑΣ ΑΣΤΥΝΟΜΕΥΣΗΣ': 'ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ1',
                                   'Unnamed: 1': '2016'})

# %%
df2 = df2.reset_index()

# %%
df2 = df2.astype({"2016": int})

# %%
df2 = df2.drop(columns=['index'])

# %%
df2
# Out:
#                                      ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ1    2016
# 0                           Παραβίαση προτεραιότητας     3733
# 1                       Παραβίαση ερυθρού Σηματοδότη    16152
# 2                               Αντικανονικοί ελιγμοί    6348
# 3                          Κίνηση στο αντίθετο ρεύμα    12329
# 4                           Αντικανονικό Προσπέρασμα    10042
# 5   Κίνηση στην αριστερή λωρίδα - Μη κίνηση στο άκ...     366
# 6                           Μη χρήση ζώνης ασφαλείας    34831
# 7                        Μη χρήση παιδικών καθισμάτων     613
# 8                                   Μη χρήση κράνους    63971
# 9                         Παραβάσεις οχημάτων (ΚΤΕΟ)    18238
# 10                             Παραβάσεις \nταχύτητας  176592
# 11                 Παραβίαση χρήσης κινητού τηλεφώνου   25381
# 12                                 Φθαρμένα ελαστικά     5140
# 13                 Παραβάσεις διαφημιστικών πινακίδων    2728
# ...

# %%
df3 = pd.read_excel('/Users/kosmas/Desktop/Columbia_Data_Studio_Projects/data-studio-projects/Weekly projects/Traffic_violations_in_Greece /troxaia-2017_paravaseis.xls')
df3.head()
# Out:
#              Α.Ε.Α. - ΔΙΕΘΥΝΣΗ ΤΡΟΧΑΙΑΣ ΑΣΤΥΝΟΜΕΥΣΗΣ  Unnamed: 1  Unnamed: 2  \
# 0                                                NaN         NaN         NaN
# 1  Πίνακας επικίνδυνων παραβάσεων\n ΕΤΟΥΣ 2017-2016          NaN         NaN
# 2                                                NaN         NaN         NaN
# 3                                    ΕΙΔΟΣ ΠΑΡΑΒΑΣΗΣ      2017.0      2016.0
# 4                          Παραβίαση προτεραιότητας       2977.0      3733.0
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3    ΔΙΑΦΟΡΑ    ΠΟΣΟΣΤΟ
# 4       -756  -0.202518

# %%
df3 = df3.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis = 1)

# %%
df3 = df3.drop([0,1,2,3])

# %%
df3 = df3.rename(index=str, columns={'Α.Ε.Α. - ΔΙΕΘΥΝΣΗ ΤΡΟΧΑΙΑΣ ΑΣΤΥΝΟΜΕΥΣΗΣ': 'ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ2',
                                   'Unnamed: 1': '2017'})

# %%
df3 = df3.reset_index()

# %%
df3 = df3.astype({"2017": int})

# %%
df3 = df3.drop(columns=['index'])

# %%
df3
# Out:
#                       ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ2    2017
# 0            Παραβίαση προτεραιότητας     2977
# 1        Παραβίαση ερυθρού Σηματοδότη    15501
# 2                Αντικανονικοί ελιγμοί    6860
# 3           Κίνηση στο αντίθετο ρεύμα    11921
# 4            Αντικανονικό Προσπέρασμα     7638
# 5         Κίνηση στην αριστερή λωρίδα      448
# 6            Μη χρήση ζώνης ασφαλείας    32500
# 7         Μη χρήση παιδικών καθισμάτων     876
# 8                    Μη χρήση κράνους    60142
# 9          Παραβάσεις οχημάτων (ΚΤΕΟ)    19309
# 10              Παραβάσεις \nταχύτητας  214132
# 11  Παραβίαση χρήσης κινητού τηλεφώνου   24127
# 12                  Φθαρμένα ελαστικά     5774
# 13  Παραβάσεις διαφημιστικών πινακίδων    3440
# 14                                Μέθη   33620
# 15                  ΣΥΝΟΛΟ ΠΑΡΑΒΑΣΕΩΝ   439265

# %%
df4 = pd.read_excel('/Users/kosmas/Desktop/Columbia_Data_Studio_Projects/data-studio-projects/Weekly projects/Traffic_violations_in_Greece /troxaia-2018_paravaseis.xls')
df4.head()
# Out:
#             Α.Ε.Α. - ΔΙΕΘΥΝΣΗ ΤΡΟΧΑΙΑΣ ΑΣΤΥΝΟΜΕΥΣΗΣ  Unnamed: 1  Unnamed: 2  \
# 0                                               NaN         NaN         NaN
# 1  Πίνακας επικίνδυνων παραβάσεων\n ΕΤΟΥΣ 2018-2017         NaN         NaN
# 2                                               NaN         NaN         NaN
# 3                                   ΕΙΔΟΣ ΠΑΡΑΒΑΣΗΣ      2018.0      2017.0
# 4                         Παραβίαση προτεραιότητας       2270.0      2928.0
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3    ΔΙΑΦΟΡΑ    ΠΟΣΟΣΤΟ
# 4       -658  -0.224727

# %%
df4 = df4.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis = 1)

# %%
df4 = df4.drop([0,1,2,3])

# %%
df4 = df4.rename(index=str, columns={'Α.Ε.Α. - ΔΙΕΘΥΝΣΗ ΤΡΟΧΑΙΑΣ ΑΣΤΥΝΟΜΕΥΣΗΣ': 'ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ3',
                                   'Unnamed: 1': '2018'})

# %%
df4 = df4.reset_index()

# %%
df4 = df4.astype({"2018": int})

# %%
df4 = df4.drop(columns=['index'])

# %%
df4
# Out:
#                                      ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ3    2018
# 0                           Παραβίαση προτεραιότητας     2270
# 1                       Παραβίαση ερυθρού Σηματοδότη    14931
# 2                               Αντικανονικοί ελιγμοί    4593
# 3                          Κίνηση στο αντίθετο ρεύμα    11364
# 4                           Αντικανονικό Προσπέρασμα     6706
# 5   Κίνηση στην αριστερή λωρίδα - Μη κίνηση στο άκ...     310
# 6                           Μη χρήση ζώνης ασφαλείας    33380
# 7                        Μη χρήση παιδικών καθισμάτων     920
# 8                                   Μη χρήση κράνους    52706
# 9                         Παραβάσεις οχημάτων (ΚΤΕΟ)    25845
# 10                               Παραβάσεις ταχύτητας  213333
# 11                 Παραβίαση χρήσης κινητού τηλεφώνου   18224
# 12                                 Φθαρμένα ελαστικά     5785
# 13                 Παραβάσεις διαφημιστικών πινακίδων    3165
# ...

# %%
df = pd.concat([df1, df2, df3, df4], axis=1, sort=False)

# %%
df = df.drop(columns=['ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ1', 'ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ2', 'ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ3'])

# %%
df = df[['ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_', '2014', '2015', '2016', '2017', '2018']]

# %%
df = df.drop([15])

# %%
df.head()
# Out:
#                 ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_   2014   2015   2016   2017   2018
# 0      Παραβίαση προτεραιότητας    3836   3927   3733   2977   2270
# 1  Παραβίαση ερυθρού Σηματοδότη   13913  14564  16152  15501  14931
# 2          Αντικανονικοί ελιγμοί   5137   5926   6348   6860   4593
# 3     Κίνηση στο αντίθετο ρεύμα   12729  11695  12329  11921  11364
# 4      Αντικανονικό Προσπέρασμα    8107   8406  10042   7638   6706

# %%
df.shape
# Out:
# (15, 6)

# %%
df.dtypes
# Out:
# ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_    object
# 2014                 int64
# 2015                 int64
# 2016                 int64
# 2017                 int64
# 2018                 int64
# dtype: object

# %%
#df.to_csv('final_violations.csv')

# %%
df = pd.read_csv('/Users/kosmas/Desktop/Columbia_Data_Studio_Projects/data-studio-projects/Weekly projects/Traffic_violations_in_Greece /final_violations.csv')
df
# Out:
#     Unnamed: 0                    ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_    2014    2015    2016  \
# 0            0            Παραβίαση προτεραιότητας    3836    3927    3733
# 1            1        Παραβίαση ερυθρού σηματοδότη   13913   14564   16152
# 2            2               Αντικανονικοί ελιγμοί    5137    5926    6348
# 3            3           Κίνηση στο αντίθετο ρεύμα   12729   11695   12329
# 4            4            Αντικανονικό προσπέρασμα    8107    8406   10042
# 5            5         Κίνηση στην αριστερή λωρίδα     297     261     366
# 6            6            Μη χρήση ζώνης ασφαλείας   34526   29611   34831
# 7            7        Μη χρήση παιδικών καθισμάτων     626     424     613
# 8            8                    Μη χρήση κράνους   54354   52783   63971
# 9            9                    Παραβάσεις ΚΤΕΟ    30683   25130   18238
# 10          10                 Υπερβολική ταχύτητα  156892  173476  176592
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ## These are my final dataframes

# %%
#My data is in wide format. Bad bad bad.
df
# Out:
#                       ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_    2014    2015    2016    2017    2018
# 0             Παραβίαση προτεραιότητας    3836    3927    3733    2977    2270
# 1         Παραβίαση ερυθρού σηματοδότη   13913   14564   16152   15501   14931
# 2                Αντικανονικοί ελιγμοί    5137    5926    6348    6860    4593
# 3            Κίνηση στο αντίθετο ρεύμα   12729   11695   12329   11921   11364
# 4             Αντικανονικό προσπέρασμα    8107    8406   10042    7638    6706
# 5          Κίνηση στην αριστερή λωρίδα     297     261     366     448     310
# 6             Μη χρήση ζώνης ασφαλείας   34526   29611   34831   32500   33380
# 7         Μη χρήση παιδικών καθισμάτων     626     424     613     876     920
# 8                     Μη χρήση κράνους   54354   52783   63971   60142   52706
# 9                     Παραβάσεις ΚΤΕΟ    30683   25130   18238   19309   25845
# 10                 Υπερβολική ταχύτητα  156892  173476  176592  214132  213333
# ...

# %%
#Now its long data format.Thank Nora.
final_df = pd.melt(df, id_vars=['ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_'], value_vars=['2014', '2015', '2016', '2017', '2018'], value_name='number_of_tickets', var_name='year')
final_df
# Out:
#                       ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_  year  number_of_tickets
# 0             Παραβίαση προτεραιότητας  2014               3836
# 1         Παραβίαση ερυθρού σηματοδότη  2014              13913
# 2                Αντικανονικοί ελιγμοί  2014               5137
# 3            Κίνηση στο αντίθετο ρεύμα  2014              12729
# 4             Αντικανονικό προσπέρασμα  2014               8107
# 5          Κίνηση στην αριστερή λωρίδα  2014                297
# 6             Μη χρήση ζώνης ασφαλείας  2014              34526
# 7         Μη χρήση παιδικών καθισμάτων  2014                626
# 8                     Μη χρήση κράνους  2014              54354
# 9                     Παραβάσεις ΚΤΕΟ   2014              30683
# 10                 Υπερβολική ταχύτητα  2014             156892
# 11             Χρήση κινητού τηλεφώνου  2014              23459
# 12                   Φθαρμένα ελαστικά  2014               5744
# 13  Παραβάσεις διαφημιστικών πινακίδων  2014               2461
# ...

# %% [markdown]
# ## Sum of tickets for violations, for all years

# %%
violations_allyears = final_df.groupby('ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_').number_of_tickets.sum().sort_values(ascending=False)
violations_allyears
# Out:
# ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_
# Υπερβολική ταχύτητα                   934425
# Μη χρήση κράνους                      283956
# Μη χρήση ζώνης ασφαλείας              164848
# Μέθη                                  158994
# Παραβάσεις ΚΤΕΟ                       119205
# Χρήση κινητού τηλεφώνου               110921
# Παραβίαση ερυθρού σηματοδότη           75061
# Κίνηση στο αντίθετο ρεύμα              60038
# Αντικανονικό προσπέρασμα               40899
# Αντικανονικοί ελιγμοί                  28864
# Φθαρμένα ελαστικά                      27620
# Παραβίαση προτεραιότητας               16743
# Παραβάσεις διαφημιστικών πινακίδων     15060
# Μη χρήση παιδικών καθισμάτων            3459
# Κίνηση στην αριστερή λωρίδα             1682
# Name: number_of_tickets, dtype: int64

# %%
violations_allyears.sort_values().plot(kind = 'barh', width=0.5, 
                                           figsize=(8, 10),
                                           title='Total number of violations for all years')

# %% [markdown]
# ## Sum of tickets  of Top 5 violations for all years

# %%
new_violations_all_years = violations_allyears.head(6)
new_violations_all_years
# Out:
# ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_
# Υπερβολική ταχύτητα         934425
# Μη χρήση κράνους            283956
# Μη χρήση ζώνης ασφαλείας    164848
# Μέθη                        158994
# Παραβάσεις ΚΤΕΟ             119205
# Χρήση κινητού τηλεφώνου     110921
# Name: number_of_tickets, dtype: int64

# %%
new_violations_all_years.sort_values().plot(kind = 'barh', width=0.4, 
                                           figsize=(7, 3),
                                           title='Total number of violations for all years')

# %%
df['total'] = df['2014'] + df['2015'] + df['2016'] + df['2017'] + df['2018']
df.head()
# Out:
#                ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_   2014   2015   2016   2017   2018  total
# 0      Παραβίαση προτεραιότητας   3836   3927   3733   2977   2270  16743
# 1  Παραβίαση ερυθρού σηματοδότη  13913  14564  16152  15501  14931  75061
# 2         Αντικανονικοί ελιγμοί   5137   5926   6348   6860   4593  28864
# 3     Κίνηση στο αντίθετο ρεύμα  12729  11695  12329  11921  11364  60038
# 4      Αντικανονικό προσπέρασμα   8107   8406  10042   7638   6706  40899

# %%
df.sort_values(by='total', ascending=False)
# Out:
#                       ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_    2014    2015    2016    2017  \
# 10                 Υπερβολική ταχύτητα  156892  173476  176592  214132
# 8                     Μη χρήση κράνους   54354   52783   63971   60142
# 6             Μη χρήση ζώνης ασφαλείας   34526   29611   34831   32500
# 14                                Μέθη   29597   29191   33192   33620
# 9                     Παραβάσεις ΚΤΕΟ    30683   25130   18238   19309
# 11             Χρήση κινητού τηλεφώνου   23459   19730   25381   24127
# 1         Παραβίαση ερυθρού σηματοδότη   13913   14564   16152   15501
# 3            Κίνηση στο αντίθετο ρεύμα   12729   11695   12329   11921
# 4             Αντικανονικό προσπέρασμα    8107    8406   10042    7638
# 2                Αντικανονικοί ελιγμοί    5137    5926    6348    6860
# 12                   Φθαρμένα ελαστικά    5744    5177    5140    5774
# 0             Παραβίαση προτεραιότητας    3836    3927    3733    2977
# ...

# %%
df.sort_values(by='total').plot(x='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_',
        y=['2014', '2015', '2016', '2017', '2018'],
        kind = 'barh',
        stacked=True,
        figsize=(10, 5),
        width=0.5,
        title='Total number of violations per year')

# %% [markdown]
# ## This is the average percent change over the years for each violation

# %%
df.head()
# Out:
#                ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_   2014   2015   2016   2017   2018  total
# 0      Παραβίαση προτεραιότητας   3836   3927   3733   2977   2270  16743
# 1  Παραβίαση ερυθρού σηματοδότη  13913  14564  16152  15501  14931  75061
# 2         Αντικανονικοί ελιγμοί   5137   5926   6348   6860   4593  28864
# 3     Κίνηση στο αντίθετο ρεύμα  12729  11695  12329  11921  11364  60038
# 4      Αντικανονικό προσπέρασμα   8107   8406  10042   7638   6706  40899

# %%
#this is the intermediate percent change from 2014 to 2015 blablabla

pct = df.copy()
pct['14_15_pct'] = (pct['2015'] - pct['2014']) / pct['2014'] * 100
pct['15_16_pct'] = (pct['2016'] - pct['2015']) / pct['2015'] * 100
pct['16_17_pct'] = (pct['2017'] - pct['2016']) / pct['2016'] * 100
pct['17_18_pct'] = (pct['2018'] - pct['2017']) / pct['2017'] * 100

pct['14_18_pct'] = (pct['2018'] - pct['2014']) / pct['2014'] * 100

pct.head()
# Out:
#                ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_   2014   2015   2016   2017   2018  total  \
# 0      Παραβίαση προτεραιότητας   3836   3927   3733   2977   2270  16743
# 1  Παραβίαση ερυθρού σηματοδότη  13913  14564  16152  15501  14931  75061
# 2         Αντικανονικοί ελιγμοί   5137   5926   6348   6860   4593  28864
# 3     Κίνηση στο αντίθετο ρεύμα  12729  11695  12329  11921  11364  60038
# 4      Αντικανονικό προσπέρασμα   8107   8406  10042   7638   6706  40899
#
#    14_15_pct  15_16_pct  16_17_pct  17_18_pct  14_18_pct
# 0   2.372263  -4.940158 -20.251808 -23.748740 -40.823775
# 1   4.679077  10.903598  -4.030461  -3.677182   7.316898
# 2  15.359159   7.121161   8.065532 -33.046647 -10.589838
# 3  -8.123183   5.421120  -3.309271  -4.672427 -10.723545
# 4   3.688171  19.462289 -23.939454 -12.202147 -17.281362

# %%
#Percent change from 2014 to 2018. It would be useful to see the biggest and the lowest change.
#or the top 5/low 5 
pct.sort_values(by='14_18_pct')
# Out:
#                       ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_    2014    2015    2016    2017  \
# 0             Παραβίαση προτεραιότητας    3836    3927    3733    2977
# 11             Χρήση κινητού τηλεφώνου   23459   19730   25381   24127
# 4             Αντικανονικό προσπέρασμα    8107    8406   10042    7638
# 9                     Παραβάσεις ΚΤΕΟ    30683   25130   18238   19309
# 3            Κίνηση στο αντίθετο ρεύμα   12729   11695   12329   11921
# 2                Αντικανονικοί ελιγμοί    5137    5926    6348    6860
# 6             Μη χρήση ζώνης ασφαλείας   34526   29611   34831   32500
# 8                     Μη χρήση κράνους   54354   52783   63971   60142
# 12                   Φθαρμένα ελαστικά    5744    5177    5140    5774
# 5          Κίνηση στην αριστερή λωρίδα     297     261     366     448
# 1         Παραβίαση ερυθρού σηματοδότη   13913   14564   16152   15501
# 14                                Μέθη   29597   29191   33192   33620
# ...

# %%
pct['14_18_pct'].sort_values().plot(kind='barh', y='14_18_pct', x='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_')

# %%
data.abs().argsort()
# Out:
# ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_
# Μη χρήση παιδικών καθισμάτων          3
# Υπερβολική ταχύτητα                   4
# Παραβάσεις διαφημιστικών πινακίδων    2
# Αντικανονικό προσπέρασμα              1
# Χρήση κινητού τηλεφώνου               5
# Παραβίαση προτεραιότητας              0
# Name: 14_18_pct, dtype: int64

# %%
data= top3.sort_values(by='14_18_pct', 
                 ascending=False).set_index('ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_')['14_18_pct']
pal = sns.color_palette("Purples_r", len(data))
rank = data.abs().argsort().argsort()
sns.barplot(y=data.index, x=data, palette=np.array(pal[::-1])[rank])

plt.show()

# %%
top3.sort_values(by='14_18_pct', 
                 ascending=False)
# Out:
#                       ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_    2014    2015    2016    2017  \
# 7         Μη χρήση παιδικών καθισμάτων     626     424     613     876
# 10                 Υπερβολική ταχύτητα  156892  173476  176592  214132
# 13  Παραβάσεις διαφημιστικών πινακίδων    2461    3266    2728    3440
# 4             Αντικανονικό προσπέρασμα    8107    8406   10042    7638
# 11             Χρήση κινητού τηλεφώνου   23459   19730   25381   24127
# 0             Παραβίαση προτεραιότητας    3836    3927    3733    2977
#
#       2018   total  14_15_pct  15_16_pct  16_17_pct  17_18_pct  14_18_pct
# 7      920    3459 -32.268371  44.575472  42.903752   5.022831  46.964856
# 10  213333  934425  10.570329   1.796214  21.258041  -0.373134  35.974428
# 13    3165   15060  32.710280 -16.472750  26.099707  -7.994186  28.606258
# 4     6706   40899   3.688171  19.462289 -23.939454 -12.202147 -17.281362
# 11   18224  110921 -15.895818  28.641662  -4.940704 -24.466365 -22.315529
# ...

# %%
top3 = pct.loc[[7,10,13,0,11,4],]
top3.sort_values(by='14_18_pct', 
                 ascending=False).plot(y='14_18_pct', 
                                       x='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_', kind='barh', color=)

# %%
top3.sort_values(by='14_18_pct', 
                 ascending=False).plot(kind='area',
                                       stacked=False,
                                       figsize=(10,6), 
                                       y='14_18_pct', 
                                       x='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_')

# %%
pct['14_18_pct'].plot(kind='area', 
                      stacked=False, 
                      figsize=(10,6), 
                      x='14_18_pct', y='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_')

# %% [markdown]
# ## Sum of all tickets per year

# %%
violations_per_year = final_df.groupby('year').number_of_tickets.sum()
violations_per_year
# Out:
# year
# 2014    382361
# 2015    383567
# 2016    409656
# 2017    439265
# 2018    426926
# Name: number_of_tickets, dtype: int64

# %%
violations_per_year.plot(kind='area', 
                      stacked=True, 
                      figsize=(10,6)) 
                      #x='14_18_pct', y='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_')

# %% [markdown]
# # Just testing stuf

# %%
#I don't know if this is useful
averages = pd.DataFrame(avg)
averages.round(2)
# Out:
#        0
# 0  18.73
# 1  18.79
# 2  20.06
# 3  21.51
# 4  20.91

# %%
violations_per_year.plot(kind='pie', title='Number of violations per year')

# %%
df.plot(x='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_', y=['2014', '2015', '2016', '2017', '2018'], kind='barh',
        width=0.8, 
        figsize=(8, 10), 
        title='Types of violations per year')

# %%
df.plot(x='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_', y=['2014', '2015', '2016', '2017', '2018'], kind='area', 
        figsize=(15, 7), 
        title='Types of violations per year')

# %%
sns.relplot(data=final_df, x='number_of_tickets', 
            y='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_', 
            col='year', 
            col_wrap=3, 
            height=3)

# %%
sns.relplot(data=final_df, 
            x='number_of_tickets', 
            y='year', 
            hue='ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_')

# %%
final_df.plot()

# %%
df.plot()

# %%
df.set_index('ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_').T
# Out:
# ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_  Παραβίαση προτεραιότητας  Παραβίαση ερυθρού σηματοδότη  \
# 2014                                  3836                         13913
# 2015                                  3927                         14564
# 2016                                  3733                         16152
# 2017                                  2977                         15501
# 2018                                  2270                         14931
#
# ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_  Αντικανονικοί ελιγμοί  Κίνηση στο αντίθετο ρεύμα  \
# 2014                               5137                      12729
# 2015                               5926                      11695
# 2016                               6348                      12329
# 2017                               6860                      11921
# 2018                               4593                      11364
#
# ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_  Αντικανονικό προσπέρασμα  Κίνηση στην αριστερή λωρίδα  \
# ...

# %%
df.set_index('ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_').T.plot(kind='area')

# %%
final_df.groupby('year').ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_.number_of_tickets.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-97b5008d6714> in <module>
# ----> 1 final_df.groupby('year').ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_.number_of_tickets.sum()
#
# ~/.pyenv/versions/3.7.1/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
# --> 536                              (type(self).__name__, attr))
#     537
#     538     @Substitution(klass='GroupBy',
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'number_of_tickets'

# %%
df.plot(x='year', y=['ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_', 'number_of_tickets'], kind='barh')

# %%
final_df.groupby('ΕΙΔΟΣ_ΠΑΡΑΒΑΣΗΣ_').year.sort_values(ascending=False)
