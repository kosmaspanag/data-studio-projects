# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/kosmas/Desktop/Columbia_Data_Studio_Projects/data-studio-projects/Weekly projects/Fires_in Greece/970c9267-5b4e-424b-9092-91bc919d4c8b.csv', encoding='UTF-8')
df.head()
# Out:
#                                         FID   ESYE_ID   GREEKNAME  PREF_ID  \
# 0    970c9267-5b4e-424b-9092-91bc919d4c8b.0  42160000    ΛΙΒΑΔΙΟΥ       42
# 1    970c9267-5b4e-424b-9092-91bc919d4c8b.1  42220000     ΟΛΥΜΠΟΥ       42
# 2    970c9267-5b4e-424b-9092-91bc919d4c8b.5  98690000     ΔΡΟΣΙΑΣ       98
# 3  970c9267-5b4e-424b-9092-91bc919d4c8b.343  71060000  ΟΡΕΣΤΙΑΔΟΣ       71
# 4  970c9267-5b4e-424b-9092-91bc919d4c8b.344  71070000       ΟΡΦΕΑ       71
#
#               PREFECTURE       EDRA  \
# 0             Ν. ΛΑΡΙΣΑΣ     ΛΙΒΑΔΙ
# 1             Ν. ΛΑΡΙΣΑΣ   ΚΑΛΛΙΘΕΑ
# 2  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ     ΔΡΟΣΙΑ
# 3               Ν. ΕΒΡΟΥ  ΟΡΕΣΤΙΑΔΑ
# 4               Ν. ΕΒΡΟΥ     ΛΑΒΑΡΑ
#
#                                             the_geom
# 0  MULTIPOLYGON (((345534.05923610553 4450741.999...
# 1  MULTIPOLYGON (((357296.50131980306 4448098.500...
# 2  MULTIPOLYGON (((488545.59262545547 4217704.002...
# 3  MULTIPOLYGON (((698833.3759813095 4604653.0014...
# ...

# %%
df[['ESYE_ID', 'PREFECTURE']]
# Out:
#        ESYE_ID             PREFECTURE
# 0     42160000             Ν. ΛΑΡΙΣΑΣ
# 1     42220000             Ν. ΛΑΡΙΣΑΣ
# 2     98690000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# 3     71060000               Ν. ΕΒΡΟΥ
# 4     71070000               Ν. ΕΒΡΟΥ
# 5     42630000             Ν. ΛΑΡΙΣΑΣ
# 6     61010000             Ν. ΠΙΕΡΙΑΣ
# 7     81100000         Ν. ΔΩΔΕΚΑΝΗΣΩΝ
# 8     81150000         Ν. ΔΩΔΕΚΑΝΗΣΩΝ
# 9     81160000         Ν. ΔΩΔΕΚΑΝΗΣΩΝ
# 10    81210000         Ν. ΔΩΔΕΚΑΝΗΣΩΝ
# 11    81610000         Ν. ΔΩΔΕΚΑΝΗΣΩΝ
# 12    84010000               Ν. ΣΑΜΟΥ
# 13    61020000             Ν. ΠΙΕΡΙΑΣ
# 14    98720000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# 15    98800000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# 16    96020000  Ν. ΠΕΙΡΑΙΩΣ ΚΑΙ ΝΗΣΩΝ
# 17    98730000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# 18    98740000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# 19    98810000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# 20    98780000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# 21    98790000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# 22    99420000              Ν. ΑΘΗΝΩΝ
# 23    98820000  Ν. ΑΝΑΤΟΛΙΚΗΣ ΑΤΤΙΚΗΣ
# ...

# %%
df[['ESYE_ID', 'PREFECTURE']].to_csv('greek_labels.csv')

# %%
df.dtypes
# Out:
# FID           object
# ESYE_ID        int64
# GREEKNAME     object
# PREF_ID        int64
# PREFECTURE    object
# EDRA          object
# the_geom      object
# dtype: object

# %%
df1 = pd.read_csv('/Users/kosmas/Desktop/Columbia_Data_Studio_Projects/data-studio-projects/Weekly projects/Fires_in Greece/c7b5978b-aca9-4d74-b8a5-d3a48d02f6d0.csv', encoding='UTF-8')
df1.head()
# Out:
#                                       FID               NAME  KWD_YPES  \
# 0  c7b5978b-aca9-4d74-b8a5-d3a48d02f6d0.0          Αμυνταίου    9070.0
# 1  c7b5978b-aca9-4d74-b8a5-d3a48d02f6d0.1               Άθως       NaN
# 2  c7b5978b-aca9-4d74-b8a5-d3a48d02f6d0.2  Άκτιου - Βόνιτσας    9124.0
# 3  c7b5978b-aca9-4d74-b8a5-d3a48d02f6d0.3             Άνδρου    9268.0
# 4  c7b5978b-aca9-4d74-b8a5-d3a48d02f6d0.4   Άργους - Μυκηνών    9233.0
#
#                                             the_geom
# 0  MULTIPOLYGON (((306603.59375000076 4524540, 30...
# 1  MULTIPOLYGON (((521237.59375 4461202, 521222.4...
# 2  MULTIPOLYGON (((221292.40624999924 4294039, 22...
# 3  MULTIPOLYGON (((584417.125000001 4171609, 5843...
# 4  MULTIPOLYGON (((369695.31250000035 4188647, 36...

# %%
df1[['NAME', 'KWD_YPES']]
# Out:
#                             NAME  KWD_YPES
# 0                      Αμυνταίου    9070.0
# 1                           Άθως       NaN
# 2              Άκτιου - Βόνιτσας    9124.0
# 3                         Άνδρου    9268.0
# 4               Άργους - Μυκηνών    9233.0
# 5                        Έδεσσας    9043.0
# 6                         Ήλιδας    9139.0
# 7                          Ιλίου    9182.0
# 8                          Ύδρας    9214.0
# 9                        Αίγινας    9208.0
# 10                       Αβδήρων    9015.0
# 11                Αγίας Βαρβάρας    9179.0
# 12              Αγίας Παρασκευής    9167.0
# 13               Αγίου Βασιλείου    9314.0
# 14               Αγίου Δημητρίου    9194.0
# 15              Αγίου Ευστρατίου    9262.0
# 16                Αγίου Νικολάου    9310.0
# 17   Αγίων Αναργύρων - Καματερού    9180.0
# 18                   Αγαθονησίου    9274.0
# 19                         Αγιάς    9097.0
# 20                    Αγκιστρίου    9207.0
# ...

# %%
df1[['NAME', 'KWD_YPES']].to_csv('greek_labels_final.csv')
